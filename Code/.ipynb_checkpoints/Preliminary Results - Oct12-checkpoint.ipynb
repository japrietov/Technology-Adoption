# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.colors import to_rgba

import numpy as np
from scipy.stats import t
from scipy.stats import norm
from scipy.stats import ttest_rel
from numpy.linalg import inv
import warnings

sns.set_style('whitegrid')
warnings. filterwarnings('ignore')

def convert_pvalue(test, pvalue):
    if pvalue <= 0.01:
        return "{:.3f}***".format(test)
    elif pvalue <= 0.05:
        return "{:.3f}***".format(test)
    elif pvalue <= 0.1:
        return "{:.3f}***".format(test)
    return "{:.3f}".format(test)

# %% [markdown]
# # Read Data

# %% [markdown]
# ## Male

# %%
df_M_raw = pd.read_stata('../Data/drive-download-20231006T131216Z-001/CMS - Spouse Cleaned/Files/Husband Responses.dta')
df_M_raw = df_M_raw[(df_M_raw['A02_Sex'] == 'Male') & 
                    (df_M_raw['A04_Marital_status'] == 'married living with spouse/s') & 
                    (df_M_raw['A06_Relatn_hhd'].isin(['Household head', 'Spouse']))].reset_index(drop=True)
df_M_raw.tail()
# Out:
#      ZoneID  StateID   LgaID  LocalityID  EnumerationID    HouseID  \
# 735     4.0     43.0  4316.0     43163.0       431631.0  4316312.0
# 736     4.0     43.0  4317.0     43171.0       431711.0  4317111.0
# 737     4.0     43.0  4318.0     43181.0       431811.0  4318111.0
# 738     4.0     43.0  4318.0     43182.0       431821.0  4318211.0
# 739     4.0     43.0  4318.0     43182.0       431821.0  4318213.0
#
#      Individual_family_code A02_Sex  A03_Age            A04_Marital_status  \
# 735                     1.0    Male     63.0  married living with spouse/s
# 736                     1.0    Male     41.0  married living with spouse/s
# 737                     1.0    Male     54.0  married living with spouse/s
# 738                     1.0    Male     72.0  married living with spouse/s
# 739                     1.0    Male     42.0  married living with spouse/s
#
#      ...  Women__Production_Value Respondent HouseHold_AnimalUnits  \
# 735  ...                   2500.0    Husband                  3.00
# 736  ...                   1200.0    Husband                  0.04
# 737  ...                    800.0    Husband                  0.00
# 738  ...                   1900.0    Husband                  1.70
# 739  ...                   5400.0    Husband                  0.50
#
#     Male_Owned_Livestock Female_Owned_Livestock  ICV  \
# 735                 0.20                   1.00  0.0
# 736                 0.04                   0.00  0.0
# 737                 0.00                   0.00  1.0
# 738                 1.00                   0.70  0.0
# 739                 0.36                   0.14  1.0
#
#      Total_Physical_Assets_Naira  Total_Processing_Asset  \
# 735                     346400.0                     4.0
# 736                    3396610.0                     4.0
# 737                   12642980.0                     4.0
# 738                   11866180.0                     4.0
# 739                    1521870.0                     4.0
#
#      Land_Operated_Cassava_Proportion  Land_Owned_Cassava_Proportion
# 735                          1.000000                       0.500000
# 736                          0.142857                       0.454545
# 737                          0.654545                       0.666667
# 738                          0.428571                       0.428571
# 739                          0.333333                       0.250000
#
# [5 rows x 164 columns]

# %% [markdown]
# ## Female

# %%
df_F_raw = pd.read_stata('../Data/drive-download-20231006T131216Z-001/Files/Wife Responses.dta')
df_F_raw = df_F_raw[(df_F_raw['A02_Sex'] == 'Female') &
                    (df_F_raw['A04_Marital_status'] == 'married living with spouse/s') & 
                    (df_F_raw['A06_Relatn_hhd'].isin(['Household head', 'Spouse']))].reset_index(drop=True)
df_F_raw.tail()
# Out:
#      ZoneID  StateID   LgaID  LocalityID  EnumerationID    HouseID  \
# 773     4.0     43.0  4316.0     43163.0       431631.0  4316312.0
# 774     4.0     43.0  4317.0     43171.0       431711.0  4317111.0
# 775     4.0     43.0  4318.0     43181.0       431811.0  4318111.0
# 776     4.0     43.0  4318.0     43182.0       431821.0  4318211.0
# 777     4.0     43.0  4318.0     43182.0       431821.0  4318213.0
#
#      Individual_family_code A02_Sex  A03_Age            A04_Marital_status  \
# 773                     1.0  Female     48.0  married living with spouse/s
# 774                     1.0  Female     38.0  married living with spouse/s
# 775                     1.0  Female     40.0  married living with spouse/s
# 776                     1.0  Female     49.0  married living with spouse/s
# 777                     1.0  Female     36.0  married living with spouse/s
#
#      ...  Women__Production_Value Respondent HouseHold_AnimalUnits  \
# 773  ...                   3600.0       Wife                  2.40
# 774  ...                   5000.0       Wife                  0.00
# 775  ...                   1100.0       Wife                  0.00
# 776  ...                   1600.0       Wife                  0.72
# 777  ...                    300.0       Wife                  0.52
#
#     Male_Owned_Livestock Female_Owned_Livestock  ICV  \
# 773                 1.00                   1.40  0.0
# 774                 0.00                   0.00  1.0
# 775                 0.00                   0.00  1.0
# 776                 0.46                   0.26  1.0
# 777                 0.20                   0.32  1.0
#
#      Total_Physical_Assets_Naira  Total_Processing_Asset  \
# 773                     185850.0                     4.0
# 774                     131700.0                     4.0
# 775                    2084000.0                     4.0
# 776                     603500.0                     4.0
# 777                    2561050.0                     4.0
#
#      Land_Operated_Cassava_Proportion  Land_Owned_Cassava_Proportion
# 773                          1.000000                       1.000000
# 774                          1.000000                       1.000000
# 775                          0.654545                       0.666667
# 776                          0.500000                       0.000000
# 777                          0.500000                       0.333333
#
# [5 rows x 164 columns]

# %% [markdown]
# ## Mixing Male and Female

# %%
df_allMF = pd.concat([df_M_raw, df_F_raw]).reset_index(drop=True)
both_responses = (df_allMF['HouseID'].value_counts()).to_frame()
# print(both_responses)
both_responses = both_responses[both_responses['count']== 2]
df_allMF = df_allMF[df_allMF['HouseID'].isin(both_responses.index)]

df_M = df_allMF[df_allMF['A02_Sex'] == 'Male']
df_M = df_M.reset_index(drop=True)

df_F = df_allMF[df_allMF['A02_Sex'] == 'Female']
df_F = df_F.reset_index(drop=True)

df_allMF['A02_Sex'].value_counts()
# Out:
# A02_Sex
# Male      729
# Female    729
# Name: count, dtype: int64

# %%
df_H_dna = pd.read_csv("../Data/CMS-raw/dna.csv")
df_H_dna[df_H_dna['HouseID']==112115]
# Out:
#    ID  StateID  EnumerationID  HouseID  CassavaPlotInformationID  Fieldcode  \
# 6   7       11          11211   112115                         1          1
# 7   8       11          11211   112115                         2          2
#
#    Plotcode  adoption
# 6         1         0
# 7         1         0

# %%
# https://data.iita.org/dataset/the-cassava-monitoring-survey-cms-in-nigeria-household-and-plot-level-data
df_H_dna = pd.read_csv("../Data/CMS-raw/dna.csv")
houseIDs = df_M['HouseID'].value_counts().keys()
df_H_dna = df_H_dna[df_H_dna['HouseID'].isin(houseIDs)].groupby('HouseID', as_index=False).agg(
    {'adoption': ['sum', 'min']})
df_H_dna.columns = ['HouseID', 'Household_ICV', 'planted']
df_H_dna.head()
# Out:
#    HouseID  Household_ICV  planted
# 0   112115              0        0
# 1   112213              1        1
# 2   112214              2        1
# 3   113113              0        0
# 4   113115              0        0

# %%
# https://data.iita.org/dataset/the-cassava-monitoring-survey-cms-in-nigeria-household-and-plot-level-data
df_H_livestock = pd.read_csv("../Data/CMS-raw/livestock_owned_all-regions.csv")
houseIDs = df_M['HouseID'].value_counts().keys()

df_H_livestock = df_H_livestock[df_H_livestock['HouseID'].isin(houseIDs)]
df_H_livestock = df_H_livestock.groupby('HouseID', as_index=False).agg({'Total_Number_of_livestk_owned': 'sum'})
df_H_livestock.columns = ['HouseID', 'HouseHold_AnimalUnits']

df_H_livestock.head()# ['Total_Number_of_livestk_owned'].equals(df_F['HouseHold_AnimalUnits'])
# Out:
#    HouseID  HouseHold_AnimalUnits
# 0   112115                   31.0
# 1   112213                   17.0
# 2   112214                   82.0
# 3   113113                   24.0
# 4   113115                   56.0

# %% [markdown]
# ## Household

# %%
originals = '../Data/drive-download-20231006T131216Z-001/CMS - Spouse Cleaned/Files/Data Cleaning - Individual Files/Original Files - Not Cleaned/CMS (entire database)/Files/'
spouse = '../Data/drive-download-20231006T131216Z-001/CMS - Spouse Cleaned/Files/Data Cleaning - Individual Files/Original Files - Not Cleaned/Spouse (wife)/'

houseIDs = df_M['HouseID'].value_counts().keys()

df_H_originals = pd.read_stata(originals+'Livestock_owned_All regions.dta')
df_H_spouse = pd.read_stata(spouse+'Livestock_owned_Spouse_All regions.dta')

df_H_originals = df_H_originals[df_H_originals['HouseID'].isin(houseIDs)]
df_H_originals = df_H_originals.groupby('HouseID', as_index=False).agg({'G01b_TNumber_owned': 'sum'})
df_H_originals.columns = ['HouseID', 'HouseHold_AnimalUnits']

df_H_spouse = df_H_spouse.groupby('HouseID', as_index=False).agg({'G01b_TNumber_owned': 'sum'})
df_H_spouse = df_H_spouse[df_H_spouse['HouseID'].isin(houseIDs)]
df_H_spouse.columns = ['HouseID', 'HouseHold_AnimalUnits']

df_H_originals[df_H_originals['HouseID'].isin([112115, 112213])]
# Out:
#     HouseID  HouseHold_AnimalUnits
# 0  112115.0                   31.0
# 1  112213.0                   17.0

# %%
df_H = pd.read_stata('../Data/drive-download-20231006T131216Z-001/CMS - Spouse Cleaned/Files/CMS Responses.dta')
df_H = df_H[df_H['HouseID'].isin(df_allMF['HouseID'].value_counts().keys())]
df_H = df_H.reset_index(drop=True)
print(df_H.shape)
# Out:
# (729, 164)

# %% [markdown]
# **Assumption $df\_H \equiv df\_M$, therefore $y_H = y_M$ and $x_H = x_M$**
#
# ### Dependend variable

# %%
for index, var in enumerate(['Household_ICV', 'planted']):
    fig1, ax1 = plt.subplots(dpi=100, figsize=(8, 6))

    ttest_HM = ttest_rel(df_H_dna[f'{var}'], df_M[f'{var}'], nan_policy='omit')
    ttest_HF = ttest_rel(df_H_dna[f'{var}'], df_F[f'{var}'], nan_policy='omit')
    ttest_MF = ttest_rel(df_M[f'{var}'], df_F[f'{var}'], nan_policy='omit')

    data = []
    data.append(['DNA-test vs Husbands', convert_pvalue(ttest_HM[0], ttest_HM[1])])
    data.append(['DNA-test vs Wives', convert_pvalue(ttest_HF[0], ttest_HF[1])])
    data.append(['Husbands vs Wives', convert_pvalue(ttest_MF[0], ttest_MF[1])])

    df_ttest = pd.DataFrame(data, columns = ['Comparison', 'T-test'])

    sns.kdeplot(df_H_dna[var], ax = ax1, fill=True, color="C2", label ="DNA-test",  alpha=0.3)
    sns.kdeplot(df_M[var], ax = ax1, fill=True, color="C0", label ="Husband self-reported",  alpha=0.3)
    sns.kdeplot(df_F[var], ax = ax1, fill=True, color="C3", label ="Wive self-reported",  alpha=0.3)
    ax1.set_xlabel(var)
    
    ax1.table(cellText=df_ttest.values, colLabels=df_ttest.columns, 
              cellLoc='left', colWidths=[0.7, 0.3], bbox = (0.55, 0.05, 0.4, 0.2), loc='lower right', zorder=10)
    ax1.legend(loc=index+1)
    # ax1.set_title(labels[index])

    ax1.set_ylabel('Density', fontweight='bold')
    ax1.set_xlabel('Y/N ICV' if var == 'planted' else 'ICV total', fontweight='bold')
    
    fig1.savefig(f"../Output/Figures/{var}.png", dpi=100, bbox_inches='tight' )

# %% [markdown]
# ### Independend variable

# %% [markdown]
# # T-paired test

# %%
df_H_livestock[df_H_livestock['HouseID'] == 112115]
# Out:
#    HouseID  HouseHold_AnimalUnits
# 0   112115                   31.0

# %%
df_M.head()
# Out:
#    ZoneID  StateID  LgaID  LocalityID  EnumerationID   HouseID  \
# 0     1.0     11.0  112.0      1121.0        11211.0  112115.0
# 1     1.0     11.0  112.0      1122.0        11221.0  112213.0
# 2     1.0     11.0  112.0      1122.0        11221.0  112214.0
# 3     1.0     11.0  113.0      1131.0        11311.0  113113.0
# 4     1.0     11.0  113.0      1131.0        11311.0  113115.0
#
#    Individual_family_code A02_Sex  A03_Age            A04_Marital_status  ...  \
# 0                     1.0    Male     48.0  married living with spouse/s  ...
# 1                     1.0    Male     60.0  married living with spouse/s  ...
# 2                     1.0    Male     77.0  married living with spouse/s  ...
# 3                     1.0    Male     65.0  married living with spouse/s  ...
# 4                     1.0    Male     45.0  married living with spouse/s  ...
#
#    Women__Production_Value Respondent HouseHold_AnimalUnits  \
# 0                   3228.0    Husband                  1.10
# 1                    900.0    Husband                  0.90
# 2                      0.0    Husband                  3.40
# 3                   1800.0    Husband                  0.96
# 4                   1000.0    Husband                  1.60
#
#   Male_Owned_Livestock Female_Owned_Livestock  ICV  \
# 0                 0.70                    0.4  0.0
# 1                 0.70                    0.2  1.0
# 2                 3.40                    0.0  1.0
# 3                 0.36                    0.6  1.0
# 4                 0.40                    1.2  0.0
#
#    Total_Physical_Assets_Naira  Total_Processing_Asset  \
# 0                    1251992.0                     2.0
# 1                    5471700.0                     2.0
# 2                    7013400.0                     2.0
# 3                    6390300.0                     1.0
# 4                    2632500.0                     1.0
#
#    Land_Operated_Cassava_Proportion  Land_Owned_Cassava_Proportion
# 0                          0.181818                       0.181818
# 1                          0.500000                       0.000000
# 2                          0.333333                       0.333333
# 3                          0.166667                       0.166667
# 4                          0.141667                       0.141667
#
# [5 rows x 164 columns]

# %%
# ['Kids', 'HouseHold_AnimalUnits', 'Credit_Access', 'Shovel_Number_Own']:
for index, var in enumerate(['HouseHold_AnimalUnits']):
    fig1, ax1 = plt.subplots(dpi=100, figsize=(8, 6))

    ttest_HM = ttest_rel(df_H_livestock[f'{var}'], df_M[f'{var}'], nan_policy='omit')
    ttest_HF = ttest_rel(df_H_livestock[f'{var}'], df_F[f'{var}'], nan_policy='omit')
    ttest_MF = ttest_rel(df_M[f'{var}'], df_F[f'{var}'], nan_policy='omit')

    data = []
    data.append(['Household vs Male', convert_pvalue(ttest_HM[0], ttest_HM[1])])
    data.append(['Household vs Female', convert_pvalue(ttest_HF[0], ttest_HF[1])])
    data.append(['Male vs Female', convert_pvalue(ttest_MF[0], ttest_MF[1])])

    df_ttest = pd.DataFrame(data, columns = ['Comparison', 'T-test'])

    sns.kdeplot(df_H_livestock[var], ax = ax1, fill=True, color="C2", label ="Household",  alpha=0.3)
    sns.kdeplot(df_M[var], ax = ax1, fill=True, color="C0", label ="Male",  alpha=0.3)
    sns.kdeplot(df_F[var], ax = ax1, fill=True, color="C3", label ="Female",  alpha=0.3)
    ax1.set_xlabel(var)
    
    ax1.table(cellText=df_ttest.values, colLabels=df_ttest.columns, 
              cellLoc='left', colWidths=[0.7, 0.3], bbox = (0.55, 0.05, 0.4, 0.2), loc='lower right', zorder=10)
    ax1.legend(loc=index+1)

# %%
tvalues = {}
for var in df_H.keys()[17:]:
    if f'{var}' in df_M.keys() and f'{var}' in df_M.keys():
        try:
            #ttest_HM = ttest_rel(df_H[f'{var}'], df_M[f'{var}'], nan_policy='omit')
            # ttest_HF = ttest_rel(df_H[f'{var}'], df_F[f'{var}'], nan_policy='omit')
            ttest_MF = ttest_rel(df_M[f'{var}'], df_F[f'{var}'], nan_policy='omit')
            
            tvalues[var] = convert_pvalue(ttest_MF[0], ttest_MF[1])
            #if ttest_MF[1] <= 0.10:
            
            print(var, 
                  convert_pvalue(df_M[f'{var}'].mean(),1), 
                  convert_pvalue(df_F[f'{var}'].mean(),1),
                  convert_pvalue(ttest_MF[0], ttest_MF[1]))
        except:
            pass
            # print(f'Error in {var}')
# Out:
# Men_In_House 2.314 2.100 4.918***
# Women_In_House 2.230 2.169 1.491
# Kids 2.763 2.599 2.135***
# Male_Managed 0.978 0.621 6.026***
# Female_Managed 0.095 0.276 -5.875***
# Joint_Managed 1.414 1.656 -3.276***
# Male_ICV_Managed 0.647 0.313 7.146***
# Female_ICV_Managed 0.063 0.167 -3.662***
# Joint_ICV_Managed 0.801 0.909 -1.803***
# Male_NonICV_Managed 0.331 0.309 0.484
# Female_NonICV_Managed 0.032 0.108 -3.960***
# Joint_NonICV_Managed 0.613 0.746 -2.456***
# Household_ICV 1.512 1.390 1.828***
# Household_NonICV 0.975 1.163 -3.160***
# Household_Plots 2.506 2.565 -1.181
# ICV_Plot_Size 9247.973 4552.396 6.253***
# NonICV_Plot_Size 3436.019 3128.278 0.728
# Male_ICV_PlotSize 4458.499 1109.005 6.470***
# Female_ICV_PlotSize 214.768 429.746 -2.656***
# Joint_ICV_PlotSize 4555.913 3013.645 2.504***
# Male_NonICV_PlotSize 1485.806 908.609 1.855***
# Female_NonICV_PlotSize 52.451 321.890 -2.185***
# Joint_NonICV_PlotSize 1849.932 1811.525 0.140
# House_Cassava_Plot_TotalSize 12683.992 7680.674 6.487***
# Avg_Plot_Size 5988.399 3524.423 6.983***
# planted 0.621 0.582 2.224***
# J05_sales_perc 56.316 56.492 -0.211
# J05_consumption_perc 34.756 33.779 1.280
# J05_Others_perc 8.984 9.753 -2.305***
# Men_Only_Coop 0.067 0.091 -1.847***
# Women_Only_Coop 0.016 0.029 -1.734***
# Joint_Coop 0.176 0.178 -0.147
# Male_Credit_Only 0.112 0.043 5.163***
# Female_Credit_Only 0.018 0.033 -1.862***
# Joint_Credit 0.321 0.303 0.804
# Credit_Access 0.451 0.379 3.193***
# Male_CreditGroup_Only 0.043 0.041 0.143
# Women_CreditGroup_Only 0.027 0.069 -3.979***
# Joint_CreditGroup 0.266 0.320 -2.610***
# Extension_Access 0.444 0.287 7.314***
# Male_Ext_Only 0.222 0.125 5.317***
# Female_Ext_Only 0.007 0.008 -0.378
# Joint_Ext_Access 0.204 0.108 6.152***
# Female_Fryer_Access 0.240 0.325 -4.687***
# Male_Fryer_Access 0.008 0.007 0.301
# Joint_Fryer_Access 0.298 0.165 7.144***
# Female_Grater_Access 0.147 0.265 -6.205***
# Male_Grater_Access 0.103 0.136 -1.963***
# Joint_Grater_Access 0.605 0.405 8.330***
# Female_Presser_Access 0.137 0.250 -5.964***
# Male_Presser_Access 0.110 0.093 1.105
# Joint_Presser_Access 0.545 0.374 7.316***
# Female_Sieve_Access 0.219 0.287 -3.759***
# Male_Sieve_Access 0.011 0.018 -1.091
# Joint_Sieve_Access 0.306 0.192 6.260***
# Male_Total_Processing_Access 0.232 0.254 -0.665
# Female_Total_Processing_Access 0.743 1.126 -6.269***
# Joint_Total_Processing_Access 1.753 1.136 8.775***
# Number_Bikes_Owned 0.299 0.228 3.338***
# Bike_Avg_value 1312.140 961.660 3.252***
# Bike_Own_Women 0.092 0.080 1.153
# Bike_Own_Men 0.207 0.147 3.212***
# Bike_Women_Value 761.454 625.034 1.374
# Bike_Men_Value 1392.112 927.161 3.068***
# Bike_Asset_Value 2153.567 1547.256 3.231***
# Number_Cell_Owned 3.184 3.037 1.662***
# Cell_Avg_value 4591.529 4494.436 0.352
# Cell_Own_Women 1.412 1.372 0.790
# Cell_Own_Men 1.775 1.683 1.541
# Cell_Women_Value 7227.340 7182.062 0.078
# Cell_Men_Value 9010.959 9569.980 -0.365
# Cell_Asset_Value 16175.885 16687.652 -0.268
# Number_Dishes_Owned 21.888 32.679 -3.386***
# Dishes_Avg_value 1369.030 2263.922 -4.296***
# Dishes_Own_Women 19.532 31.782 -3.804***
# Dishes_Own_Men 2.594 1.008 4.843***
# Dishes_Women_Value 30982.025 63729.395 -3.060***
# Dishes_Men_Value 7773.781 3967.785 0.801
# Dishes_Asset_Value 38194.762 67703.344 -2.510***
# Number_Jewel_Owned 10.554 3.706 0.712
# Jewel_Avg_value 2139.438 1534.911 1.293
# Jewel_Own_Women 10.417 3.388 0.731
# Jewel_Own_Men 0.137 0.309 -2.034***
# Jewel_Women_Value 43019.137 12984.773 0.990
# Jewel_Men_Value 1033.745 1044.033 -0.032
# Jewel_Asset_Value 44052.879 14055.556 0.988
# Number_Motos_Owned 0.926 0.903 0.756
# Moto_Avg_value 36016.230 36788.429 -0.443
# Moto_Own_Women 0.095 0.114 -1.548
# Moto_Own_Men 0.830 0.778 1.726***
# Moto_Women_Value 6305.350 6184.746 0.130
# Moto_Men_Value 45576.906 45686.344 -0.034
# Moto_Asset_Value 51895.977 52336.109 -0.130
# Number_Radios_Owned 1.398 3.365 -0.956
# Radio_Avg_value 2427.945 2246.584 1.005
# Radio_Own_Women 0.204 0.207 -0.093
# Radio_Own_Men 1.196 1.099 2.360***
# Radio_Women_Value 612.033 493.529 0.919
# Radio_Men_Value 3646.365 3108.676 1.839***
# Radio_Asset_Value 4237.890 9776.006 -0.896
# Total_Household_Asset_Value 113067418.453 5504918.883 3.965***
# Women_Owned_HHAsset_Value 4529368.632 180325.849 1.057
# Male_Owned_HHAsset_Value 108519916.754 5323069.999 3.939***
# Hoe_Number_Own 4.835 4.520 2.113***
# Hoe_Avg_Value 843.734 725.627 3.922***
# Women_Hoe_Own 1.262 1.487 -2.844***
# Men_Hoe_Own 3.575 3.021 3.978***
# Hoe_Total_Value 4049.171 3318.169 3.327***
# Male_Hoe_Value 3116.498 2232.545 4.703***
# Women_Hoe_Value 927.941 1082.606 -1.944***
# Shovel_Number_Own 1.368 1.410 -0.552
# Shovel_Avg_Value 654.742 683.502 -0.858
# Women_Shovel_Own 0.162 0.165 -0.122
# Men_Shovel_Own 1.203 1.232 -0.384
# Shovel_Total_Value 1547.368 1647.639 -0.720
# Male_Shovel_Value 1364.926 1473.798 -0.801
# Women_Shovel_Value 178.738 153.333 1.020
# Total_Production_Asset_Value 1493651.395 260541.357 0.888
# Male__Production_Value 1484778.878 359289.624 0.808
# Women__Production_Value 6732.584 8178.545 -0.618
# HouseHold_AnimalUnits 1.873 1.984 -0.156
# Male_Owned_Livestock 1.373 0.939 1.960***
# Female_Owned_Livestock 0.498 1.045 -0.985
# Land_Operated_Cassava_Proportion 0.515 0.535 -1.617
# Land_Owned_Cassava_Proportion 0.408 0.454 -3.068***
