# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.colors import to_rgba

import numpy as np
from scipy.stats import t
from scipy.stats import norm
from scipy.stats import ttest_rel
from numpy.linalg import inv
import warnings

sns.set_style('whitegrid')
warnings. filterwarnings('ignore')

def convert_pvalue(test, pvalue):
    if pvalue <= 0.01:
        return "{:.4f}***".format(test)
    elif pvalue <= 0.05:
        return "{:.4f}***".format(test)
    elif pvalue <= 0.1:
        return "{:.4f}***".format(test)
    return "{:.4f}".format(test)

# %% [markdown]
# # Read Data

# %% [markdown]
# ## Male

# %%
df_M_raw = pd.read_stata('../Data/drive-download-20231006T131216Z-001/CMS - Spouse Cleaned/Files/Husband Responses.dta')
df_M_raw = df_M_raw[(df_M_raw['A02_Sex'] == 'Male') & 
                    (df_M_raw['A04_Marital_status'] == 'married living with spouse/s') & 
                    (df_M_raw['A06_Relatn_hhd'].isin(['Household head', 'Spouse']))].reset_index(drop=True)
df_M_raw.tail()
# Out:
#      ZoneID  StateID   LgaID  LocalityID  EnumerationID    HouseID  \
# 735     4.0     43.0  4316.0     43163.0       431631.0  4316312.0
# 736     4.0     43.0  4317.0     43171.0       431711.0  4317111.0
# 737     4.0     43.0  4318.0     43181.0       431811.0  4318111.0
# 738     4.0     43.0  4318.0     43182.0       431821.0  4318211.0
# 739     4.0     43.0  4318.0     43182.0       431821.0  4318213.0
#
#      Individual_family_code A02_Sex  A03_Age            A04_Marital_status  \
# 735                     1.0    Male     63.0  married living with spouse/s
# 736                     1.0    Male     41.0  married living with spouse/s
# 737                     1.0    Male     54.0  married living with spouse/s
# 738                     1.0    Male     72.0  married living with spouse/s
# 739                     1.0    Male     42.0  married living with spouse/s
#
#      ...  Women__Production_Value Respondent HouseHold_AnimalUnits  \
# 735  ...                   2500.0    Husband                  3.00
# 736  ...                   1200.0    Husband                  0.04
# 737  ...                    800.0    Husband                  0.00
# 738  ...                   1900.0    Husband                  1.70
# 739  ...                   5400.0    Husband                  0.50
#
#     Male_Owned_Livestock Female_Owned_Livestock  ICV  \
# 735                 0.20                   1.00  0.0
# 736                 0.04                   0.00  0.0
# 737                 0.00                   0.00  1.0
# 738                 1.00                   0.70  0.0
# 739                 0.36                   0.14  1.0
#
#      Total_Physical_Assets_Naira  Total_Processing_Asset  \
# 735                     346400.0                     4.0
# 736                    3396610.0                     4.0
# 737                   12642980.0                     4.0
# 738                   11866180.0                     4.0
# 739                    1521870.0                     4.0
#
#      Land_Operated_Cassava_Proportion  Land_Owned_Cassava_Proportion
# 735                          1.000000                       0.500000
# 736                          0.142857                       0.454545
# 737                          0.654545                       0.666667
# 738                          0.428571                       0.428571
# 739                          0.333333                       0.250000
#
# [5 rows x 164 columns]

# %% [markdown]
# ## Female

# %%
df_F_raw = pd.read_stata('../Data/drive-download-20231006T131216Z-001/Files/Wife Responses.dta')
df_F_raw = df_F_raw[(df_F_raw['A02_Sex'] == 'Female') &
                    (df_F_raw['A04_Marital_status'] == 'married living with spouse/s') & 
                    (df_F_raw['A06_Relatn_hhd'].isin(['Household head', 'Spouse']))].reset_index(drop=True)
df_F_raw.tail()
# Out:
#      ZoneID  StateID   LgaID  LocalityID  EnumerationID    HouseID  \
# 773     4.0     43.0  4316.0     43163.0       431631.0  4316312.0
# 774     4.0     43.0  4317.0     43171.0       431711.0  4317111.0
# 775     4.0     43.0  4318.0     43181.0       431811.0  4318111.0
# 776     4.0     43.0  4318.0     43182.0       431821.0  4318211.0
# 777     4.0     43.0  4318.0     43182.0       431821.0  4318213.0
#
#      Individual_family_code A02_Sex  A03_Age            A04_Marital_status  \
# 773                     1.0  Female     48.0  married living with spouse/s
# 774                     1.0  Female     38.0  married living with spouse/s
# 775                     1.0  Female     40.0  married living with spouse/s
# 776                     1.0  Female     49.0  married living with spouse/s
# 777                     1.0  Female     36.0  married living with spouse/s
#
#      ...  Women__Production_Value Respondent HouseHold_AnimalUnits  \
# 773  ...                   3600.0       Wife                  2.40
# 774  ...                   5000.0       Wife                  0.00
# 775  ...                   1100.0       Wife                  0.00
# 776  ...                   1600.0       Wife                  0.72
# 777  ...                    300.0       Wife                  0.52
#
#     Male_Owned_Livestock Female_Owned_Livestock  ICV  \
# 773                 1.00                   1.40  0.0
# 774                 0.00                   0.00  1.0
# 775                 0.00                   0.00  1.0
# 776                 0.46                   0.26  1.0
# 777                 0.20                   0.32  1.0
#
#      Total_Physical_Assets_Naira  Total_Processing_Asset  \
# 773                     185850.0                     4.0
# 774                     131700.0                     4.0
# 775                    2084000.0                     4.0
# 776                     603500.0                     4.0
# 777                    2561050.0                     4.0
#
#      Land_Operated_Cassava_Proportion  Land_Owned_Cassava_Proportion
# 773                          1.000000                       1.000000
# 774                          1.000000                       1.000000
# 775                          0.654545                       0.666667
# 776                          0.500000                       0.000000
# 777                          0.500000                       0.333333
#
# [5 rows x 164 columns]

# %% [markdown]
# ## Mixing Male and Female

# %%
df_allMF = pd.concat([df_M_raw, df_F_raw]).reset_index(drop=True)
both_responses = (df_allMF['HouseID'].value_counts()).to_frame()
both_responses = both_responses[both_responses['HouseID']== 2]
df_allMF = df_allMF[df_allMF['HouseID'].isin(both_responses.index)]

df_M = df_allMF[df_allMF['A02_Sex'] == 'Male']
df_M = df_M.reset_index(drop=True)

df_F = df_allMF[df_allMF['A02_Sex'] == 'Female']
df_F = df_F.reset_index(drop=True)

df_allMF['A02_Sex'].value_counts()
# Out:
# Male      729
# Female    729
# Name: A02_Sex, dtype: int64

# %%
df_H_dna = pd.read_csv("../Data/CMS-raw/dna.csv")
df_H_dna[df_H_dna['HouseID']==112115]
# Out:
#    ID  StateID  EnumerationID  HouseID  CassavaPlotInformationID  Fieldcode  \
# 6   7       11          11211   112115                         1          1
# 7   8       11          11211   112115                         2          2
#
#    Plotcode  adoption
# 6         1         0
# 7         1         0

# %%
# https://data.iita.org/dataset/the-cassava-monitoring-survey-cms-in-nigeria-household-and-plot-level-data
df_H_dna = pd.read_csv("../Data/CMS-raw/dna.csv")
houseIDs = df_M['HouseID'].value_counts().keys()
df_H_dna = df_H_dna[df_H_dna['HouseID'].isin(houseIDs)].groupby('HouseID', as_index=False).agg(
    {'adoption': ['sum', 'min']})
df_H_dna.columns = ['HouseID', 'Household_ICV', 'planted']
df_H_dna.head()
# Out:
#    HouseID  Household_ICV  planted
# 0   112115              0        0
# 1   112213              1        1
# 2   112214              2        1
# 3   113113              0        0
# 4   113115              0        0

# %%
# https://data.iita.org/dataset/the-cassava-monitoring-survey-cms-in-nigeria-household-and-plot-level-data
df_H_livestock = pd.read_csv("../Data/CMS-raw/livestock_owned_all-regions.csv")
houseIDs = df_M['HouseID'].value_counts().keys()

df_H_livestock = df_H_livestock[df_H_livestock['HouseID'].isin(houseIDs)]
df_H_livestock = df_H_livestock.groupby('HouseID', as_index=False).agg({'Total_Number_of_livestk_owned': 'sum'})
df_H_livestock.columns = ['HouseID', 'HouseHold_AnimalUnits']

df_H_livestock.head()# ['Total_Number_of_livestk_owned'].equals(df_F['HouseHold_AnimalUnits'])
# Out:
#    HouseID  HouseHold_AnimalUnits
# 0   112115                   31.0
# 1   112213                   17.0
# 2   112214                   82.0
# 3   113113                   24.0
# 4   113115                   56.0

# %% [markdown]
# ## Household

# %%
originals = '../Data/drive-download-20231006T131216Z-001/CMS - Spouse Cleaned/Files/Data Cleaning - Individual Files/Original Files - Not Cleaned/CMS (entire database)/Files/'
spouse = '../Data/drive-download-20231006T131216Z-001/CMS - Spouse Cleaned/Files/Data Cleaning - Individual Files/Original Files - Not Cleaned/Spouse (wife)/'

houseIDs = df_M['HouseID'].value_counts().keys()

df_H_originals = pd.read_stata(originals+'Livestock_owned_All regions.dta')
df_H_spouse = pd.read_stata(spouse+'Livestock_owned_Spouse_All regions.dta')

df_H_originals = df_H_originals[df_H_originals['HouseID'].isin(houseIDs)]
df_H_originals = df_H_originals.groupby('HouseID', as_index=False).agg({'G01b_TNumber_owned': 'sum'})
df_H_originals.columns = ['HouseID', 'HouseHold_AnimalUnits']

df_H_spouse = df_H_spouse.groupby('HouseID', as_index=False).agg({'G01b_TNumber_owned': 'sum'})
df_H_spouse = df_H_spouse[df_H_spouse['HouseID'].isin(houseIDs)]
df_H_spouse.columns = ['HouseID', 'HouseHold_AnimalUnits']

df_H_originals[df_H_originals['HouseID'].isin([112115, 112213])]
# Out:
#     HouseID  HouseHold_AnimalUnits
# 0  112115.0                   31.0
# 1  112213.0                   17.0

# %%
df_H = pd.read_stata('../Data/drive-download-20231006T131216Z-001/CMS - Spouse Cleaned/Files/CMS Responses.dta')
df_H = df_H[df_H['HouseID'].isin(df_allMF['HouseID'].value_counts().keys())]
df_H = df_H.reset_index(drop=True)
print(df_H.shape)
# Out:
# (729, 164)

# %% [markdown]
# **Assumption $df\_H \equiv df\_M$, therefore $y_H = y_M$ and $x_H = x_M$**
#
# ### Dependend variable

# %%
for index, var in enumerate(['Household_ICV', 'planted']):
    fig1, ax1 = plt.subplots(dpi=100, figsize=(8, 6))

    ttest_HM = ttest_rel(df_H_dna[f'{var}'], df_M[f'{var}'], nan_policy='omit')
    ttest_HF = ttest_rel(df_H_dna[f'{var}'], df_F[f'{var}'], nan_policy='omit')
    ttest_MF = ttest_rel(df_M[f'{var}'], df_F[f'{var}'], nan_policy='omit')

    data = []
    data.append(['Household vs Male', convert_pvalue(ttest_HM[0], ttest_HM[1])])
    data.append(['Household vs Female', convert_pvalue(ttest_HF[0], ttest_HF[1])])
    data.append(['Male vs Female', convert_pvalue(ttest_MF[0], ttest_MF[1])])

    df_ttest = pd.DataFrame(data, columns = ['Comparison', 'T-test'])

    sns.kdeplot(df_H_dna[var], ax = ax1, fill=True, color="C2", label ="Household (DNA-Fingerprinting)",  alpha=0.3)
    sns.kdeplot(df_M[var], ax = ax1, fill=True, color="C0", label ="Male",  alpha=0.3)
    sns.kdeplot(df_F[var], ax = ax1, fill=True, color="C3", label ="Female",  alpha=0.3)
    ax1.set_xlabel(var)
    
    ax1.table(cellText=df_ttest.values, colLabels=df_ttest.columns, 
              cellLoc='left', colWidths=[0.7, 0.3], bbox = (0.55, 0.05, 0.4, 0.2), loc='lower right', zorder=10)
    ax1.legend(loc=index+1)
    # ax1.set_title(labels[index])
    
    fig1.savefig(f"../Output/Figures/{var}.png", dpi=100, bbox_inches='tight' )

# %% [markdown]
# ### Independend variable

# %% [markdown]
# # T-paired test

# %%
df_H_livestock[df_H_livestock['HouseID'] == 112115]
# Out:
#    HouseID  HouseHold_AnimalUnits
# 0   112115                   31.0

# %%
df_M.head()
# Out:
#    ZoneID  StateID  LgaID  LocalityID  EnumerationID   HouseID  \
# 0     1.0     11.0  112.0      1121.0        11211.0  112115.0
# 1     1.0     11.0  112.0      1122.0        11221.0  112213.0
# 2     1.0     11.0  112.0      1122.0        11221.0  112214.0
# 3     1.0     11.0  113.0      1131.0        11311.0  113113.0
# 4     1.0     11.0  113.0      1131.0        11311.0  113115.0
#
#    Individual_family_code A02_Sex  A03_Age            A04_Marital_status  ...  \
# 0                     1.0    Male     48.0  married living with spouse/s  ...
# 1                     1.0    Male     60.0  married living with spouse/s  ...
# 2                     1.0    Male     77.0  married living with spouse/s  ...
# 3                     1.0    Male     65.0  married living with spouse/s  ...
# 4                     1.0    Male     45.0  married living with spouse/s  ...
#
#    Women__Production_Value Respondent HouseHold_AnimalUnits  \
# 0                   3228.0    Husband                  1.10
# 1                    900.0    Husband                  0.90
# 2                      0.0    Husband                  3.40
# 3                   1800.0    Husband                  0.96
# 4                   1000.0    Husband                  1.60
#
#   Male_Owned_Livestock Female_Owned_Livestock  ICV  \
# 0                 0.70                    0.4  0.0
# 1                 0.70                    0.2  1.0
# 2                 3.40                    0.0  1.0
# 3                 0.36                    0.6  1.0
# 4                 0.40                    1.2  0.0
#
#    Total_Physical_Assets_Naira  Total_Processing_Asset  \
# 0                    1251992.0                     2.0
# 1                    5471700.0                     2.0
# 2                    7013400.0                     2.0
# 3                    6390300.0                     1.0
# 4                    2632500.0                     1.0
#
#    Land_Operated_Cassava_Proportion  Land_Owned_Cassava_Proportion
# 0                          0.181818                       0.181818
# 1                          0.500000                       0.000000
# 2                          0.333333                       0.333333
# 3                          0.166667                       0.166667
# 4                          0.141667                       0.141667
#
# [5 rows x 164 columns]

# %%
# ['Kids', 'HouseHold_AnimalUnits', 'Credit_Access', 'Shovel_Number_Own']:
for index, var in enumerate(['HouseHold_AnimalUnits']):
    fig1, ax1 = plt.subplots(dpi=100, figsize=(8, 6))

    ttest_HM = ttest_rel(df_H_livestock[f'{var}'], df_M[f'{var}'], nan_policy='omit')
    ttest_HF = ttest_rel(df_H_livestock[f'{var}'], df_F[f'{var}'], nan_policy='omit')
    ttest_MF = ttest_rel(df_M[f'{var}'], df_F[f'{var}'], nan_policy='omit')

    data = []
    data.append(['Household vs Male', convert_pvalue(ttest_HM[0], ttest_HM[1])])
    data.append(['Household vs Female', convert_pvalue(ttest_HF[0], ttest_HF[1])])
    data.append(['Male vs Female', convert_pvalue(ttest_MF[0], ttest_MF[1])])

    df_ttest = pd.DataFrame(data, columns = ['Comparison', 'T-test'])

    sns.kdeplot(df_H_livestock[var], ax = ax1, fill=True, color="C2", label ="Household",  alpha=0.3)
    sns.kdeplot(df_M[var], ax = ax1, fill=True, color="C0", label ="Male",  alpha=0.3)
    sns.kdeplot(df_F[var], ax = ax1, fill=True, color="C3", label ="Female",  alpha=0.3)
    ax1.set_xlabel(var)
    
    ax1.table(cellText=df_ttest.values, colLabels=df_ttest.columns, 
              cellLoc='left', colWidths=[0.7, 0.3], bbox = (0.55, 0.05, 0.4, 0.2), loc='lower right', zorder=10)
    ax1.legend(loc=index+1)

# %%
tvalues = {}
for var in df_H.keys()[17:]:
    if f'{var}' in df_M.keys() and f'{var}' in df_M.keys():
        try:
            #ttest_HM = ttest_rel(df_H[f'{var}'], df_M[f'{var}'], nan_policy='omit')
            # ttest_HF = ttest_rel(df_H[f'{var}'], df_F[f'{var}'], nan_policy='omit')
            ttest_MF = ttest_rel(df_M[f'{var}'], df_F[f'{var}'], nan_policy='omit')
            
            tvalues[var] = convert_pvalue(ttest_MF[0], ttest_MF[1])
            #if ttest_MF[1] <= 0.10:
            
            print(var, 
                  # df_H[f'{var}'].equals(df_M[f'{var}']),
                  convert_pvalue(ttest_MF[0], ttest_MF[1]))
        except:
            pass
            # print(f'Error in {var}')
# Out:
# Men_In_House 4.9184***
# Women_In_House 1.4905
# Kids 2.1353***
# Male_Managed 6.0257***
# Female_Managed -5.8751***
# Joint_Managed -3.2765***
# Male_ICV_Managed 7.1458***
# Female_ICV_Managed -3.6622***
# Joint_ICV_Managed -1.8034***
# Male_NonICV_Managed 0.4844
# Female_NonICV_Managed -3.9601***
# Joint_NonICV_Managed -2.4557***
# Household_ICV 1.8276***
# Household_NonICV -3.1598***
# Household_Plots -1.1807
# ICV_Plot_Size 6.2534***
# NonICV_Plot_Size 0.7282
# Male_ICV_PlotSize 6.4697***
# Female_ICV_PlotSize -2.6558***
# Joint_ICV_PlotSize 2.5038***
# Male_NonICV_PlotSize 1.8551***
# Female_NonICV_PlotSize -2.1849***
# Joint_NonICV_PlotSize 0.1396
# House_Cassava_Plot_TotalSize 6.4868***
# Avg_Plot_Size 6.9829***
# planted 2.2237***
# J02_per_hh_inc_cassav -0.8727
# J03_women_incm -2.1399***
# J04_hhd_food_incm -1.6403
# J05_sales_perc -0.2111
# J05_consumption_perc 1.2796
# J05_Others_perc -2.3050***
# Men_Only_Coop -1.8470***
# Women_Only_Coop -1.7344***
# Joint_Coop -0.1473
# Male_Credit_Only 5.1632***
# Female_Credit_Only -1.8625***
# Joint_Credit 0.8045
# Credit_Access 3.1930***
# Male_CreditGroup_Only 0.1428
# Women_CreditGroup_Only -3.9791***
# Joint_CreditGroup -2.6103***
# Extension_Access 7.3143***
# Male_Ext_Only 5.3168***
# Female_Ext_Only -0.3777
# Joint_Ext_Access 6.1523***
# Female_Fryer_Access -4.6872***
# Male_Fryer_Access 0.3013
# Joint_Fryer_Access 7.1442***
# Female_Grater_Access -6.2046***
# Male_Grater_Access -1.9634***
# Joint_Grater_Access 8.3302***
# Female_Presser_Access -5.9641***
# Male_Presser_Access 1.1049
# Joint_Presser_Access 7.3156***
# Female_Sieve_Access -3.7588***
# Male_Sieve_Access -1.0912
# Joint_Sieve_Access 6.2601***
# Male_Total_Processing_Access -0.6653
# Female_Total_Processing_Access -6.2686***
# Joint_Total_Processing_Access 8.7750***
# Number_Bikes_Owned 3.3384***
# Bike_Avg_value 3.2519***
# Bike_Own_Women 1.1526
# Bike_Own_Men 3.2124***
# Bike_Women_Value 1.3743
# Bike_Men_Value 3.0683***
# Bike_Asset_Value 3.2312***
# Number_Cell_Owned 1.6616***
# Cell_Avg_value 0.3517
# Cell_Own_Women 0.7900
# Cell_Own_Men 1.5414
# Cell_Women_Value 0.0776
# Cell_Men_Value -0.3649
# Cell_Asset_Value -0.2679
# Number_Dishes_Owned -3.3864***
# Dishes_Avg_value -4.2957***
# Dishes_Own_Women -3.8037***
# Dishes_Own_Men 4.8434***
# Dishes_Women_Value -3.0600***
# Dishes_Men_Value 0.8009
# Dishes_Asset_Value -2.5096***
# Number_Jewel_Owned 0.7118
# Jewel_Avg_value 1.2929
# Jewel_Own_Women 0.7313
# Jewel_Own_Men -2.0340***
# Jewel_Women_Value 0.9903
# Jewel_Men_Value -0.0316
# Jewel_Asset_Value 0.9881
# Number_Motos_Owned 0.7563
# Moto_Avg_value -0.4425
# Moto_Own_Women -1.5475
# Moto_Own_Men 1.7261***
# Moto_Women_Value 0.1298
# Moto_Men_Value -0.0341
# Moto_Asset_Value -0.1303
# Number_Radios_Owned -0.9563
# Radio_Avg_value 1.0049
# Radio_Own_Women -0.0932
# Radio_Own_Men 2.3597***
# Radio_Women_Value 0.9185
# Radio_Men_Value 1.8389***
# Radio_Asset_Value -0.8958
# Total_Household_Asset_Value 3.9650***
# Women_Owned_HHAsset_Value 1.0566
# Male_Owned_HHAsset_Value 3.9392***
# Hoe_Number_Own 2.1129***
# Hoe_Avg_Value 3.9220***
# Women_Hoe_Own -2.8438***
# Men_Hoe_Own 3.9780***
# Hoe_Total_Value 3.3272***
# Male_Hoe_Value 4.7031***
# Women_Hoe_Value -1.9437***
# Shovel_Number_Own -0.5522
# Shovel_Avg_Value -0.8583
# Women_Shovel_Own -0.1216
# Men_Shovel_Own -0.3835
# Shovel_Total_Value -0.7202
# Male_Shovel_Value -0.8009
# Women_Shovel_Value 1.0197
# Total_Production_Asset_Value 0.8881
# Male__Production_Value 0.8080
# Women__Production_Value -0.6185
# HouseHold_AnimalUnits -0.1556
# Male_Owned_Livestock 1.9602***
# Female_Owned_Livestock -0.9853
# Land_Operated_Cassava_Proportion -1.6168
# Land_Owned_Cassava_Proportion -3.0681***
