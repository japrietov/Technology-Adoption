# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
path_raw =  '../Data/drive-download-20231006T131216Z-001/Files/Data Cleaning - Individual Files/Original Files - Not Cleaned/CMS (entire database)/Files/'

# %% [markdown]
# # CMS Responses

# %%
df_CMS = pd.read_stata('../Data/drive-download-20231006T131216Z-001/Files/CMS Responses.dta')
df_CMS.head()
# Out:
#    ZoneID  StateID  LgaID  LocalityID  EnumerationID   HouseID  \
# 0     1.0     11.0  112.0      1121.0        11211.0  112111.0
# 1     1.0     11.0  112.0      1121.0        11211.0  112112.0
# 2     1.0     11.0  112.0      1121.0        11211.0  112113.0
# 3     1.0     11.0  112.0      1121.0        11211.0  112114.0
# 4     1.0     11.0  112.0      1121.0        11211.0  112115.0
#
#    Individual_family_code          A01_Name_hhd_member A02_Sex  A03_Age  ...  \
# 0                     1.0               MOHAMMED ALIYU    Male     47.0  ...
# 1                     1.0         H. R. H U. O Lapinni    Male     78.0  ...
# 2                     1.0             Abdurrahman Amed    Male     45.0  ...
# 3                     1.0  Mrs. Mulikatu Iyabo Ibrahim  Female     42.0  ...
# 4                     1.0          Alh. Muhammed Elega    Male     48.0  ...
#
#   Male_Shovel_Value  Women_Shovel_Value Total_Production_Asset_Value  \
# 0             600.0                 0.0                      16800.0
# 1            1200.0                 0.0                      21200.0
# 2               0.0                 0.0                       3650.0
# 3               0.0                 0.0                      13200.0
# 4               0.0                 0.0                      32896.0
#
#   Male__Production_Value Women__Production_Value HouseHold_AnimalUnits  \
# 0                 9150.0                  7650.0                  0.68
# 1                21200.0                     0.0                  1.38
# 2                 1450.0                  2200.0                  0.70
# 3                 3470.0                  9730.0                  0.34
# 4                29668.0                  3228.0                  1.10
#
#   Male_Owned_Livestock  Female_Owned_Livestock  \
# 0                 0.64                    0.04
# 1                 1.10                    0.28
# 2                 0.00                    0.70
# 3                 0.12                    0.22
# 4                 0.70                    0.40
#
#    Land_Operated_Cassava_Proportion  Land_Owned_Cassava_Proportion
# 0                          0.600000                       0.600000
# 1                          0.090909                       0.090909
# 2                          0.333333                       0.333333
# 3                          0.203822                       0.203822
# 4                          0.181818                       0.181818
#
# [5 rows x 164 columns]

# %% [markdown]
# # DNA Fingerprinting

# %%
# https://data.iita.org/dataset/the-cassava-monitoring-survey-cms-in-nigeria-household-and-plot-level-data
df_DNA = pd.read_csv("../Data/CMS-raw/dna.csv")
houseIDs = df_CMS['HouseID'].value_counts().keys()
df_DNA = df_DNA[df_DNA['HouseID'].isin(houseIDs)].groupby('HouseID', as_index=False).agg(
    {'StateID': 'min', 'adoption': ['sum', 'min']})
df_DNA.columns = ['HouseID', 'ZoneID', 'Total ICV - DNA', 'Y/N ICV - DNA']
df_DNA['ZoneID'] = (df_DNA['ZoneID']/10).astype(int)#.tail()
df_DNA.head()
# Out:
#    HouseID  ZoneID  Total ICV - DNA  Y/N ICV - DNA
# 0   112111       1                1              1
# 1   112112       1                1              1
# 2   112113       1                3              1
# 3   112114       1                0              0
# 4   112115       1                0              0

# %% [markdown]
# # Gender and DNA fingerprinting HHhead
# **Merge:** CMS Responses and  DNA fingerprinting + A06_Relatn_hhd == Household head

# %%
df_CMS_HH  = df_CMS[df_CMS['A06_Relatn_hhd'] == 'Household head']
df_CMS_HH  = df_CMS_HH.rename(columns={'Household_ICV': 'Total ICV - Survey', 'planted': 'Y/N ICV - Survey',})
df_CMS_HH_DNA = pd.merge(df_DNA, df_CMS_HH[['HouseID', 'A02_Sex', 'Total ICV - Survey', 'Y/N ICV - Survey']], on='HouseID')
print('CMS + DNA dimensions', df_CMS_HH_DNA.shape)
print('Percentaje', df_CMS_HH_DNA['A02_Sex'].value_counts(normalize=True))
df_CMS_HH_DNA.head()
# Out:
# CMS + DNA dimensions (2115, 7)
# Percentaje A02_Sex
# Male      0.877899
# Female    0.122101
# Name: proportion, dtype: float64
#    HouseID  ZoneID  Total ICV - DNA  Y/N ICV - DNA A02_Sex  \
# 0   112111       1                1              1    Male
# 1   112112       1                1              1    Male
# 2   112113       1                3              1    Male
# 3   112114       1                0              0  Female
# 4   112115       1                0              0    Male
#
#    Total ICV - Survey  Y/N ICV - Survey
# 0                 1.0               0.0
# 1                 0.0               0.0
# 2                 3.0               1.0
# 3                 0.0               0.0
# 4                 0.0               0.0

# %%
fig1, ax1 = plt.subplots(1, 2, figsize=(12,4))
sns.kdeplot(ax = ax1[0], data=df_CMS_HH_DNA[df_CMS_HH_DNA['A02_Sex'] == 'Male'][['Total ICV - Survey', 'Total ICV - DNA']])
sns.kdeplot(ax = ax1[1], data=df_CMS_HH_DNA[df_CMS_HH_DNA['A02_Sex'] == 'Female'][['Total ICV - Survey', 'Total ICV - DNA']])

fig2, ax2 = plt.subplots(1, 2, figsize=(12,4))
sns.kdeplot(ax = ax2[0], data=df_CMS_HH_DNA[df_CMS_HH_DNA['A02_Sex'] == 'Male'][['Y/N ICV - Survey', 'Y/N ICV - DNA']])
sns.kdeplot(ax = ax2[1], data=df_CMS_HH_DNA[df_CMS_HH_DNA['A02_Sex'] == 'Female'][['Y/N ICV - Survey', 'Y/N ICV - DNA']])


ax1[0].set_title('Male')
ax2[0].set_title('Male')

ax1[1].set_title('Female')
ax2[1].set_title('Female')

fig1.suptitle('Total ICV', fontsize=16)
fig2.suptitle('Y/N ICV', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Y/N ICV')

# %% [markdown]
# # Cassava monitoring (HH head name & GIS)

# %%
df_Monitoring = pd.read_stata(path_raw + 'Cassava_monitoring_All regions.dta')  
df_Monitoring# .head()#keys()
# Out:
#       ZoneID  StateID   LgaID  LocalityID  EnumerationID    HouseID  \
# 0        1.0     11.0  1110.0     11101.0       111011.0  1110111.0
# 1        1.0     11.0  1110.0     11101.0       111011.0  1110112.0
# 2        1.0     11.0  1110.0     11101.0       111011.0  1110113.0
# 3        1.0     11.0  1110.0     11101.0       111011.0  1110114.0
# 4        1.0     11.0  1110.0     11101.0       111011.0  1110115.0
# ...      ...      ...     ...         ...            ...        ...
# 2482     4.0     43.0  4316.0     43162.0       431622.0  4316224.0
# 2483     4.0     43.0  4316.0     43162.0       431622.0  4316221.0
# 2484     4.0     43.0  4316.0     43162.0       431622.0  4316222.0
# 2485     4.0     43.0  4316.0     43162.0       431622.0  4316223.0
# 2486     4.0     43.0  4316.0     43162.0       431622.0  4316224.0
#
#       Longitude  Latitude  Altitude           Hhead_name            Resp_name  \
# 0       6.84741   7.69744     215.0      Winifred Waniko      Winifred Waniko
# 1       6.84673   7.70044     163.0     Festus Mawo Bagi     Festus Mawo Bagi
# 2       6.84686   7.69953     167.0        Mathias Shaka        Mathias Shaka
# 3       6.50810   7.42020     189.0           Peter Agam           Peter Agam
# 4       6.50824   7.41861     185.0           AwomElisha          Awom Elisha
# ...         ...       ...       ...                  ...                  ...
# 2482    5.81578   5.41990      17.0       Robinson Okoro       Robinson Okoro
# 2483    5.81605   5.41976      74.0          Okoro Happy          Okoro Happy
# 2484    5.81635   5.41900       0.0  Justina Edeuchmurhe  Justina Edeuchmurhe
# 2485    5.81457   5.42092      12.0        Adu Irikevwie        Adu Irikevwie
# 2486    5.81578   5.41990      17.0       Robinson Okoro       Robinson Okoro
#
#       Relatnsh_hhead     Mobile_no          Interviewer_name  \
# 0     Household head  8.081387e+09  A. Elisha Hyelni Mshelia
# 1     Household Head  9.096290e+09            Abdullahi Audu
# 2     Household head  8.129250e+09             Ojo.S.Olusayo
# 3     Household head  9.099637e+09  Ibrahim Ismail  Akinropo
# 4               Head  8.092252e+09               Yusuf Kabir
# ...              ...           ...                       ...
# 2482  Household head  8.059059e+09       Uchenna Christopher
# 2483  Household head  8.152748e+09          Okonkwo Innocent
# 2484  Household head  8.110033e+09            Ukeje Blessing
# 2485  Household Head  8.103022e+09           Olaniyi Abiodun
# 2486  Household head  8.059059e+09       Uchenna Christopher
#
#               Supervisor_name Date_checked           Start_time  \
# 0                  Iliya Musa               01/09/2015 16:34:29
# 1                 Dr Adetunji               01/09/2015 16:48:16
# 2                    Dr Tunji               01/09/2015 16:08:17
# 3     Dr. Adetunji Olanrewaju               01/09/2015 15:57:42
# 4              Dr. Olanrewaju               01/09/2015 17:34:00
# ...                       ...          ...                  ...
# 2482              Mark Tokula               25/09/2015 08:42:56
# 2483              Mark Tokula               25/09/2015 05:42:55
# 2484              Mark Tokula               25/09/2015 06:20:53
# 2485              Mark Tokula               24/09/2015 10:24:24
# 2486              Mark Tokula               25/09/2015 08:42:56
#
#       J13_GPS_UnitID                                       K02_lastword  \
# 0                4.0  The interview was success, their was not good ...
# 1                5.0  The farmer cooperates and response to the all ...
# 2                3.0  There is no cassava processing machine in our ...
# 3                2.0  The interview was successfully carrieout with ...
# 4               11.0                      The interview was successful.
# ...              ...                                                ...
# 2482             0.0  The farmer needs soft loan to help him in cass...
# 2483            45.0  Oil spilage has a problem of low fertility of ...
# 2484             0.0  I need cassava stems and financial support for...
# 2485            47.0  I need agro-allied chemical for weed control f...
# 2486             0.0  The farmer needs soft loan to help him in cass...
#
#                   Endtime
# 0     01/09/2015 17:33:28
# 1     01/09/2015 21:29:00
# 2     01/09/2015 21:35:35
# 3     01/09/2015 18:32:59
# 4     01/09/2015 20:34:57
# ...                   ...
# 2482  25/09/2015 09:12:22
# 2483  25/09/2015 06:18:09
# 2484  25/09/2015 07:20:56
# 2485  24/09/2015 11:24:09
# 2486  25/09/2015 09:12:22
#
# [2487 rows x 20 columns]

# %% [markdown]
# # Household composition

# %%
path_raw =  '../Data/drive-download-20231006T131216Z-001/Files/Data Cleaning - Individual Files/Original Files - Not Cleaned/CMS (entire database)/Files/'
df_HHcomposition = pd.read_stata(path_raw + 'Household_composition_All regions.dta')  
df_HHcomposition# .head(40)# .keys()
# Out:
#        ZoneID  StateID   LgaID  LocalityID  EnumerationID    HouseID  \
# 0         1.0     11.0  1110.0     11101.0       111011.0  1110112.0
# 1         1.0     11.0  1110.0     11101.0       111011.0  1110112.0
# 2         1.0     11.0  1110.0     11101.0       111011.0  1110112.0
# 3         1.0     11.0  1110.0     11101.0       111011.0  1110112.0
# 4         1.0     11.0  1110.0     11101.0       111011.0  1110112.0
# ...       ...      ...     ...         ...            ...        ...
# 11149     4.0     43.0  4316.0     43162.0       431622.0  4316224.0
# 11150     4.0     43.0  4316.0     43162.0       431622.0  4316224.0
# 11151     4.0     43.0  4316.0     43162.0       431622.0  4316224.0
# 11152     4.0     43.0  4316.0     43162.0       431622.0  4316224.0
# 11153     4.0     43.0  4316.0     43162.0       431622.0  4316224.0
#
#        Individual_family_code A01_Name_hhd_member A02_Sex  A03_Age  \
# 0                         2.0       Cathrina Bagi  Female     55.0
# 1                         3.0       Naedogbo Bagi  Female     50.0
# 2                         4.0          Titus Bagi    Male     21.0
# 3                         5.0         Sunday Bagi    Male     38.0
# 4                         6.0        Timothy Bagi    Male     50.0
# ...                       ...                 ...     ...      ...
# 11149                     5.0        Festus Okoro    Male     20.0
# 11150                     3.0        Chukwu Okoro    Male     13.0
# 11151                     1.0      Robinson Okoro    Male     60.0
# 11152                     2.0      Victoria Okoro  Female     35.0
# 11153                     4.0          John Okoro    Male     30.0
#
#       A03_2_AGECHECK            A04_Marital_status  A05_Edu  A06_Relatn_hhd  \
# 0                Yes                 Other specify     12.0          Spouse
# 1                Yes                 Other specify     12.0          Spouse
# 2                Yes  married living with spouse/s     14.0    Son/Daughter
# 3                Yes  married living with spouse/s     16.0    Son/Daughter
# 4                Yes  married living with spouse/s     15.0    Son/Daughter
# ...              ...                           ...      ...             ...
# 11149            Yes                 Never married     12.0          Spouse
# 11150            Yes                 Never married      6.0    Son/Daughter
# 11151            Yes  married living with spouse/s      6.0  Household head
# 11152            Yes  married living with spouse/s      6.0          Spouse
# 11153            Yes  married living with spouse/s     14.0    Son/Daughter
#
#            A07_1_Main_occupatn A07_1b_S_OCCUPATION A07_2_Secondary_occupation  \
# 0      Farming(crop+livestock)                  No                        NaN
# 1      Farming(crop+livestock)                  No                        NaN
# 2          Salaried employment                 Yes    Farming(crop+livestock)
# 3          Salaried employment                 Yes    Farming(crop+livestock)
# 4       Self employed off farm                 Yes    Farming(crop+livestock)
# ...                        ...                 ...                        ...
# 11149  Farming(crop+livestock)                  No                        NaN
# 11150     School/college child                  No                        NaN
# 11151  Farming(crop+livestock)                  No                        NaN
# 11152  Farming(crop+livestock)                  No                        NaN
# 11153   Self employed off farm                 Yes    Farming(crop+livestock)
#
#       A08_fam_lab_contributn A08_2_PROPORTIONCHECK
# 0                       100%                   Yes
# 1                       100%                   Yes
# 2                        50%                   Yes
# 3                        50%                   Yes
# 4                        50%                   Yes
# ...                      ...                   ...
# 11149                   100%                   Yes
# 11150                    10%                   Yes
# 11151                   100%                   Yes
# 11152                   100%                   Yes
# 11153                    50%                   Yes
#
# [11154 rows x 19 columns]
